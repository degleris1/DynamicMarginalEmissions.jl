# %%
import sys
sys.executable
# Out:
# '/Users/apple/.julia/conda/3/bin/python'

# %%
import sys
sys.path.append("/Users/apple/Documents/GitHub/CarbonNetworks.jl")
import src.open_evil_pickle
import src.make_files as mf

# %%
df_co2, df_elec = mf.load_datasets()

# %%
df_co2
print(df_co2.info)
# Out:
# <bound method DataFrame.info of                            CO2_AEC-MISO_ID  CO2_AEC-SOCO_ID  CO2_AECI-MISO_ID  \
# 2018-07-01 00:00:00+00:00     53910.238614    126306.850701      48503.471201
# 2018-07-01 01:00:00+00:00     55659.969400    126785.749731     179851.395724
# 2018-07-01 02:00:00+00:00     54917.238769    100362.721240     272562.624457
# 2018-07-01 03:00:00+00:00     48236.292386     88842.372601     183041.374856
# 2018-07-01 04:00:00+00:00     43002.546305     83812.044113     -37755.463848
# ...                                    ...              ...               ...
# 2021-06-30 16:00:00+00:00     -8484.081403     60388.240739     355370.871284
# 2021-06-30 17:00:00+00:00     -8750.090840     62349.196241     277113.953789
# 2021-06-30 18:00:00+00:00    -11138.454541     76555.763224     214838.522207
# 2021-06-30 19:00:00+00:00     -1153.702262     73696.818692     150784.875565
# 2021-06-30 20:00:00+00:00      1879.086394     67990.882615     113169.643208
#
# ...

# %%
df_elec
print(df_elec.info)
# Out:
# <bound method DataFrame.info of                            EBA.AEC-ALL.D.H  EBA.AEC-ALL.NG.COL.H  \
# 2018-07-01 00:00:00+00:00       852.088828            395.589543
# 2018-07-01 01:00:00+00:00       821.171036            399.680353
# 2018-07-01 02:00:00+00:00       762.904264            381.317775
# 2018-07-01 03:00:00+00:00       707.077333            351.154277
# 2018-07-01 04:00:00+00:00       641.677343            266.336549
# ...                                    ...                   ...
# 2021-06-30 16:00:00+00:00       651.012478              1.000000
# 2021-06-30 17:00:00+00:00       667.720988              1.000000
# 2021-06-30 18:00:00+00:00       758.234206              1.000000
# 2021-06-30 19:00:00+00:00       783.325396              1.000000
# 2021-06-30 20:00:00+00:00       788.249022              1.000000
#
#                            EBA.AEC-ALL.NG.H  EBA.AEC-ALL.NG.NG.H  \
# 2018-07-01 00:00:00+00:00       1127.315688           726.630120
# ...
